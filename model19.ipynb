# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler, PowerTransformer
from sklearn.metrics import classification_report, f1_score
import xgboost as xgb
from datetime import datetime
from sklearn.decomposition import PCA

def prepare_data(df):
    """
    Enhanced data preparation with advanced feature engineering
    """
    # Create a copy to avoid modifying original data
    data = df.copy()
    
    # Fill missing values with appropriate strategies
    numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = data.select_dtypes(include=['object']).columns
    
    # Fill numeric columns with median
    for col in numeric_cols:
        data[col] = data[col].fillna(data[col].median())
    
    # Fill categorical columns with mode
    for col in categorical_cols:
        data[col] = data[col].fillna(data[col].mode()[0])
    
    # Convert date columns to datetime and extract features
    date_cols = ['Date_Registered', 'payment_datetime', 'purchased_datetime', 
                 'released_date', 'estimated_delivery_date', 'received_date']
    
    for col in date_cols:
        if col in data.columns:
            data[col] = pd.to_datetime(data[col], errors='coerce')
            # Extract numerical features from dates
            data[f'{col}_year'] = data[col].dt.year.fillna(-1).astype(int)
            data[f'{col}_month'] = data[col].dt.month.fillna(-1).astype(int)
            data[f'{col}_day'] = data[col].dt.day.fillna(-1).astype(int)
            data[f'{col}_dayofweek'] = data[col].dt.dayofweek.fillna(-1).astype(int)
            data[f'{col}_quarter'] = data[col].dt.quarter.fillna(-1).astype(int)
            data[f'{col}_is_weekend'] = (data[col].dt.dayofweek >= 5).astype(int)
            data[f'{col}_is_month_end'] = (data[col].dt.is_month_end).astype(int)
            data[f'{col}_is_month_start'] = (data[col].dt.is_month_start).astype(int)
            data[f'{col}_hour'] = data[col].dt.hour.fillna(-1).astype(int)
    
    # Calculate time differences between all date pairs
    date_cols_dt = [col for col in date_cols if col in data.columns]
    for i in range(len(date_cols_dt)):
        for j in range(i + 1, len(date_cols_dt)):
            col1, col2 = date_cols_dt[i], date_cols_dt[j]
            diff_name = f'{col1.split("_")[0]}_{col2.split("_")[0]}_diff_days'
            data[diff_name] = (data[col2] - data[col1]).dt.total_seconds() / (24*3600)
    
    # Drop original date columns
    for col in date_cols:
        if col in data.columns:
            data = data.drop(columns=[col])
    
    # Create price-related features
    if 'Product_value' in data.columns and 'final_payment' in data.columns:
        data['price_per_loyalty_point'] = data['Product_value'] / (data['loyalty_points_redeemed'].clip(1))

        data['discount_amount'] = data['Product_value'] - data['final_payment']
        data['discount_percentage'] = (data['discount_amount'] / data['Product_value'] * 100).clip(0, 100)
        data['price_tier'] = pd.qcut(data['Product_value'], q=10, labels=False, duplicates='drop')
        data['price_to_loyalty_ratio'] = data['Product_value'] / (data['loyalty_points_redeemed'] + 1)
        
        # Log transform price features
        data['log_product_value'] = np.log1p(data['Product_value'])
        data['log_final_payment'] = np.log1p(data['final_payment'])
    
    # Enhanced loyalty features
    if 'loyalty_points_redeemed' in data.columns:
        data['has_redeemed_points'] = (data['loyalty_points_redeemed'] > 0).astype(int)
        data['log_loyalty_points'] = np.log1p(data['loyalty_points_redeemed'])
        data['points_to_value_ratio'] = data['loyalty_points_redeemed'] / (data['Product_value'] + 1)
    
    # Aggregate discount features
    discount_cols = [col for col in data.columns if 'discount_percentage' in col]
    if discount_cols:
        data['total_discount'] = data[discount_cols].sum(axis=1)
        data['max_discount'] = data[discount_cols].max(axis=1)
        data['min_discount'] = data[discount_cols].min(axis=1)
        data['discount_range'] = data['max_discount'] - data['min_discount']
    
    # Interaction features
    if 'loyalty_tier' in data.columns:
        data['loyalty_tier'] = data['loyalty_tier'].astype(str)
        data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
        data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
    
    # Encode categorical variables with target encoding
    categorical_cols = ['Gender', 'Is_current_loyalty_program_member', 'loyalty_tier',
                       'payment_method', 'purchase_medium', 'shipping_method',
                       'product_category']
    
    # Only encode categorical columns that exist in the dataset
    existing_cat_cols = [col for col in categorical_cols if col in data.columns]
    
    # Use LabelEncoder for categorical variables
    le_dict = {}
    for col in existing_cat_cols:
        le_dict[col] = LabelEncoder()
        data[col] = le_dict[col].fit_transform(data[col].astype(str))
        
    return data

# Load datasets
print("Loading datasets...")
train_data = pd.read_csv('train_dataset.csv')
test_data = pd.read_csv('test_dataset.csv')

print("\nTrain data shape:", train_data.shape)
print("Test data shape:", test_data.shape)

# Prepare features
print("\nPreparing features...")
X_train_full = prepare_data(train_data)
X_test = prepare_data(test_data)

# Remove non-feature columns from training data
cols_to_drop = ['customer_experience', 'user_id', 'transaction_id', 
                'order_id', 'tracking_number']
feature_cols = [col for col in X_train_full.columns 
                if col not in cols_to_drop]

X = X_train_full[feature_cols]
y = train_data['customer_experience']

# Scale numerical features and apply power transform
numeric_features = X.select_dtypes(include=['float64', 'int64']).columns
scaler = StandardScaler()
power = PowerTransformer(method='yeo-johnson')

X_numeric = X[numeric_features]
X_numeric_scaled = scaler.fit_transform(X_numeric)
X_numeric_transformed = power.fit_transform(X_numeric_scaled)
X[numeric_features] = X_numeric_transformed

# Add PCA features
pca = PCA(n_components=10)
pca_features = pca.fit_transform(X_numeric_transformed)
for i in range(pca_features.shape[1]):
    X[f'pca_feature_{i}'] = pca_features[:, i]

print("\nNumber of features:", len(X.columns))

# Encode target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.15,  # changed from 0.2
    random_state=42, 
    stratify=y
)

# Prepare test data
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
X_test_numeric = X_test[numeric_features]
X_test_numeric_scaled = scaler.transform(X_test_numeric)
X_test_numeric_transformed = power.transform(X_test_numeric_scaled)
X_test[numeric_features] = X_test_numeric_transformed

# Add PCA features to test data
test_pca_features = pca.transform(X_test_numeric_transformed)
for i in range(test_pca_features.shape[1]):
    X_test[f'pca_feature_{i}'] = test_pca_features[:, i]

# Optimized XGBoost parameters
params = {
    'n_estimators': 1000,  # keep same
    'max_depth': 9,        # increased from 7
    'learning_rate': 0.02,  # increased from 0.01
    'subsample': 0.9,      # increased from 0.8
    'colsample_bytree': 0.9,  # increased from 0.8
    'min_child_weight': 1,    # decreased from 3
    'gamma': 0.04,           # decreased from 0.1
    'alpha': 0.04,           # decreased from 0.1
    'lambda': 0.7,           # decreased from 1
    'objective': 'multi:softprob',
    'eval_metric': 'mlogloss',
    'random_state': 42,
    'n_jobs': -1,
    'tree_method': 'hist',
    'early_stopping_rounds': 32,  # increased from 10
    'grow_policy': 'lossguide'    # added this
}

# Initialize and train model with StratifiedKFold
print("\nTraining XGBoost model with cross-validation...")
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
cv_scores = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_train, y_train), 1):
    X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_fold_train, y_fold_val = y_train[train_idx], y_train[val_idx]
    
    fold_model = xgb.XGBClassifier(**params)
    fold_model.fit(
        X_fold_train, y_fold_train,
        eval_set=[(X_fold_val, y_fold_val)],
        verbose=False
    )
    
    fold_pred = fold_model.predict(X_fold_val)
    fold_score = f1_score(y_fold_val, fold_pred, average='weighted')
    cv_scores.append(fold_score)
    print(f"Fold {fold} F1 Score: {fold_score:.4f}")

print(f"\nMean CV F1 score: {np.mean(cv_scores):.4f} (+/- {np.std(cv_scores) * 2:.4f})")

# Train final model on full training data
print("\nTraining final model...")
final_model = xgb.XGBClassifier(**params)
final_model.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# Make predictions on validation set
y_pred = final_model.predict(X_val)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=le.classes_))

# Calculate weighted F1 score
weighted_f1 = f1_score(y_val, y_pred, average='weighted')
print(f"\nWeighted F1 Score: {weighted_f1:.4f}")

# Feature importance analysis
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': final_model.feature_importances_
})
print("\nTop 10 Most Important Features:")
print(feature_importance.sort_values('importance', ascending=False).head(10))

# Make predictions on test set
print("\nMaking predictions on test set...")
test_predictions = final_model.predict(X_test)
test_predictions_labels = le.inverse_transform(test_predictions)

# Create submission file
submission = pd.DataFrame({
    'id': range(len(test_predictions_labels)),
    'customer_experience': test_predictions_labels
})

# Save submission file
submission.to_csv('submission19.csv', index=False)
print("\nSubmission file created successfully!")
# Out:
# Loading datasets...
#
# Train data shape: (206969, 26)
# Test data shape: (137971, 25)
#
# Preparing features...
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['max_discount'] = data[discount_cols].max(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['min_discount'] = data[discount_cols].min(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['discount_range'] = data['max_discount'] - data['min_discount']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['min_discount'] = data[discount_cols].min(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['discount_range'] = data['max_discount'] - data['min_discount']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numeric_features] = X_numeric_transformed
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8128\4265696579.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# Number of features: 110
#
# Training XGBoost model with cross-validation...
# Fold 1 F1 Score: 0.6958
# Fold 2 F1 Score: 0.6945
# Fold 3 F1 Score: 0.6943
# Fold 4 F1 Score: 0.6934
# Fold 5 F1 Score: 0.6970
#
# Mean CV F1 score: 0.6950 (+/- 0.0025)
#
# Training final model...
# [0]	validation_0-mlogloss:1.09187
# [1]	validation_0-mlogloss:1.08214
# [2]	validation_0-mlogloss:1.07226
# [3]	validation_0-mlogloss:1.06273
# [4]	validation_0-mlogloss:1.05349
# [5]	validation_0-mlogloss:1.04454
# [6]	validation_0-mlogloss:1.03583
# [7]	validation_0-mlogloss:1.02744
# [8]	validation_0-mlogloss:1.01927
# [9]	validation_0-mlogloss:1.01137
# [10]	validation_0-mlogloss:1.00371
# [11]	validation_0-mlogloss:0.99660
# [12]	validation_0-mlogloss:0.98937
# [13]	validation_0-mlogloss:0.98237
# [14]	validation_0-mlogloss:0.97591
# [15]	validation_0-mlogloss:0.96929
# [16]	validation_0-mlogloss:0.96285
# [17]	validation_0-mlogloss:0.95657
# [18]	validation_0-mlogloss:0.95049
# [19]	validation_0-mlogloss:0.94457
# [20]	validation_0-mlogloss:0.93888
# [21]	validation_0-mlogloss:0.93459
# [22]	validation_0-mlogloss:0.92917
# [23]	validation_0-mlogloss:0.92387
# [24]	validation_0-mlogloss:0.91870
# [25]	validation_0-mlogloss:0.91372
# [26]	validation_0-mlogloss:0.90886
# [27]	validation_0-mlogloss:0.90410
# [28]	validation_0-mlogloss:0.90058
# [29]	validation_0-mlogloss:0.89605
# [30]	validation_0-mlogloss:0.89167
# [31]	validation_0-mlogloss:0.88772
# [32]	validation_0-mlogloss:0.88350
# [33]	validation_0-mlogloss:0.87943
# [34]	validation_0-mlogloss:0.87646
# [35]	validation_0-mlogloss:0.87291
# [36]	validation_0-mlogloss:0.86910
# [37]	validation_0-mlogloss:0.86543
# [38]	validation_0-mlogloss:0.86186
# [39]	validation_0-mlogloss:0.85836
# [40]	validation_0-mlogloss:0.85511
# [41]	validation_0-mlogloss:0.85183
# [42]	validation_0-mlogloss:0.84890
# [43]	validation_0-mlogloss:0.84576
# [44]	validation_0-mlogloss:0.84271
# [45]	validation_0-mlogloss:0.84051
# [46]	validation_0-mlogloss:0.83771
# [47]	validation_0-mlogloss:0.83562
# [48]	validation_0-mlogloss:0.83281
# [49]	validation_0-mlogloss:0.83031
# [50]	validation_0-mlogloss:0.82789
# [51]	validation_0-mlogloss:0.82601
# [52]	validation_0-mlogloss:0.82359
# [53]	validation_0-mlogloss:0.82132
# [54]	validation_0-mlogloss:0.81895
# [55]	validation_0-mlogloss:0.81659
# [56]	validation_0-mlogloss:0.81429
# [57]	validation_0-mlogloss:0.81205
# [58]	validation_0-mlogloss:0.80985
# [59]	validation_0-mlogloss:0.80772
# [60]	validation_0-mlogloss:0.80567
# [61]	validation_0-mlogloss:0.80361
# [62]	validation_0-mlogloss:0.80219
# [63]	validation_0-mlogloss:0.80033
# [64]	validation_0-mlogloss:0.79905
# [65]	validation_0-mlogloss:0.79714
# [66]	validation_0-mlogloss:0.79531
# [67]	validation_0-mlogloss:0.79354
# [68]	validation_0-mlogloss:0.79182
# [69]	validation_0-mlogloss:0.79012
# [70]	validation_0-mlogloss:0.78854
# [71]	validation_0-mlogloss:0.78741
# [72]	validation_0-mlogloss:0.78583
# [73]	validation_0-mlogloss:0.78431
# [74]	validation_0-mlogloss:0.78278
# [75]	validation_0-mlogloss:0.78132
# [76]	validation_0-mlogloss:0.77985
# [77]	validation_0-mlogloss:0.77847
# [78]	validation_0-mlogloss:0.77716
# [79]	validation_0-mlogloss:0.77584
# [80]	validation_0-mlogloss:0.77493
# [81]	validation_0-mlogloss:0.77368
# [82]	validation_0-mlogloss:0.77246
# [83]	validation_0-mlogloss:0.77126
# [84]	validation_0-mlogloss:0.77005
# [85]	validation_0-mlogloss:0.76936
# [86]	validation_0-mlogloss:0.76820
# [87]	validation_0-mlogloss:0.76706
# [88]	validation_0-mlogloss:0.76596
# [89]	validation_0-mlogloss:0.76488
# [90]	validation_0-mlogloss:0.76385
# [91]	validation_0-mlogloss:0.76284
# [92]	validation_0-mlogloss:0.76184
# [93]	validation_0-mlogloss:0.76087
# [94]	validation_0-mlogloss:0.75993
# [95]	validation_0-mlogloss:0.75906
# [96]	validation_0-mlogloss:0.75817
# [97]	validation_0-mlogloss:0.75734
# [98]	validation_0-mlogloss:0.75648
# [99]	validation_0-mlogloss:0.75561
# [100]	validation_0-mlogloss:0.75481
# [101]	validation_0-mlogloss:0.75399
# [102]	validation_0-mlogloss:0.75316
# [103]	validation_0-mlogloss:0.75273
# [104]	validation_0-mlogloss:0.75196
# [105]	validation_0-mlogloss:0.75121
# [106]	validation_0-mlogloss:0.75047
# [107]	validation_0-mlogloss:0.74977
# [108]	validation_0-mlogloss:0.74907
# [109]	validation_0-mlogloss:0.74842
# [110]	validation_0-mlogloss:0.74772
# [111]	validation_0-mlogloss:0.74708
# [112]	validation_0-mlogloss:0.74644
# [113]	validation_0-mlogloss:0.74585
# [114]	validation_0-mlogloss:0.74525
# [115]	validation_0-mlogloss:0.74465
# [116]	validation_0-mlogloss:0.74410
# [117]	validation_0-mlogloss:0.74351
# [118]	validation_0-mlogloss:0.74297
# [119]	validation_0-mlogloss:0.74246
# [120]	validation_0-mlogloss:0.74193
# [121]	validation_0-mlogloss:0.74139
# [122]	validation_0-mlogloss:0.74084
# [123]	validation_0-mlogloss:0.74032
# [124]	validation_0-mlogloss:0.73980
# [125]	validation_0-mlogloss:0.73932
# [126]	validation_0-mlogloss:0.73882
# [127]	validation_0-mlogloss:0.73838
# [128]	validation_0-mlogloss:0.73794
# [129]	validation_0-mlogloss:0.73752
# [130]	validation_0-mlogloss:0.73711
# [131]	validation_0-mlogloss:0.73671
# [132]	validation_0-mlogloss:0.73630
# [133]	validation_0-mlogloss:0.73588
# [134]	validation_0-mlogloss:0.73547
# [135]	validation_0-mlogloss:0.73507
# [136]	validation_0-mlogloss:0.73470
# [137]	validation_0-mlogloss:0.73429
# [138]	validation_0-mlogloss:0.73392
# [139]	validation_0-mlogloss:0.73374
# [140]	validation_0-mlogloss:0.73339
# [141]	validation_0-mlogloss:0.73304
# [142]	validation_0-mlogloss:0.73270
# [143]	validation_0-mlogloss:0.73235
# [144]	validation_0-mlogloss:0.73201
# [145]	validation_0-mlogloss:0.73168
# [146]	validation_0-mlogloss:0.73138
# [147]	validation_0-mlogloss:0.73122
# [148]	validation_0-mlogloss:0.73090
# [149]	validation_0-mlogloss:0.73062
# [150]	validation_0-mlogloss:0.73035
# [151]	validation_0-mlogloss:0.73007
# [152]	validation_0-mlogloss:0.72979
# [153]	validation_0-mlogloss:0.72952
# [154]	validation_0-mlogloss:0.72924
# [155]	validation_0-mlogloss:0.72897
# [156]	validation_0-mlogloss:0.72870
# [157]	validation_0-mlogloss:0.72842
# [158]	validation_0-mlogloss:0.72818
# [159]	validation_0-mlogloss:0.72803
# [160]	validation_0-mlogloss:0.72788
# [161]	validation_0-mlogloss:0.72765
# [162]	validation_0-mlogloss:0.72742
# [163]	validation_0-mlogloss:0.72732
# [164]	validation_0-mlogloss:0.72710
# [165]	validation_0-mlogloss:0.72690
# [166]	validation_0-mlogloss:0.72669
# [167]	validation_0-mlogloss:0.72645
# [168]	validation_0-mlogloss:0.72634
# [169]	validation_0-mlogloss:0.72611
# [170]	validation_0-mlogloss:0.72590
# [171]	validation_0-mlogloss:0.72567
# [172]	validation_0-mlogloss:0.72554
# [173]	validation_0-mlogloss:0.72537
# [174]	validation_0-mlogloss:0.72517
# [175]	validation_0-mlogloss:0.72494
# [176]	validation_0-mlogloss:0.72478
# [177]	validation_0-mlogloss:0.72456
# [178]	validation_0-mlogloss:0.72439
# [179]	validation_0-mlogloss:0.72421
# [180]	validation_0-mlogloss:0.72402
# [181]	validation_0-mlogloss:0.72385
# [182]	validation_0-mlogloss:0.72367
# [183]	validation_0-mlogloss:0.72350
# [184]	validation_0-mlogloss:0.72333
# [185]	validation_0-mlogloss:0.72320
# [186]	validation_0-mlogloss:0.72303
# [187]	validation_0-mlogloss:0.72290
# [188]	validation_0-mlogloss:0.72276
# [189]	validation_0-mlogloss:0.72260
# [190]	validation_0-mlogloss:0.72246
# [191]	validation_0-mlogloss:0.72230
# [192]	validation_0-mlogloss:0.72212
# [193]	validation_0-mlogloss:0.72197
# [194]	validation_0-mlogloss:0.72184
# [195]	validation_0-mlogloss:0.72171
# [196]	validation_0-mlogloss:0.72160
# [197]	validation_0-mlogloss:0.72150
# [198]	validation_0-mlogloss:0.72136
# [199]	validation_0-mlogloss:0.72123
# [200]	validation_0-mlogloss:0.72113
# [201]	validation_0-mlogloss:0.72102
# [202]	validation_0-mlogloss:0.72088
# [203]	validation_0-mlogloss:0.72078
# [204]	validation_0-mlogloss:0.72069
# [205]	validation_0-mlogloss:0.72057
# [206]	validation_0-mlogloss:0.72046
# [207]	validation_0-mlogloss:0.72033
# [208]	validation_0-mlogloss:0.72022
# [209]	validation_0-mlogloss:0.72014
# [210]	validation_0-mlogloss:0.72004
# [211]	validation_0-mlogloss:0.71995
# [212]	validation_0-mlogloss:0.71985
# [213]	validation_0-mlogloss:0.71981
# [214]	validation_0-mlogloss:0.71971
# [285]	validation_0-mlogloss:0.71606
# [286]	validation_0-mlogloss:0.71604
# [287]	validation_0-mlogloss:0.71602
# [288]	validation_0-mlogloss:0.71599
# [289]	validation_0-mlogloss:0.71597
# [290]	validation_0-mlogloss:0.71595
# [291]	validation_0-mlogloss:0.71592
# [292]	validation_0-mlogloss:0.71589
# [293]	validation_0-mlogloss:0.71586
# [294]	validation_0-mlogloss:0.71584
# [295]	validation_0-mlogloss:0.71582
# [296]	validation_0-mlogloss:0.71578
# [297]	validation_0-mlogloss:0.71576
# [298]	validation_0-mlogloss:0.71576
# [299]	validation_0-mlogloss:0.71576
# [300]	validation_0-mlogloss:0.71572
# [301]	validation_0-mlogloss:0.71569
# [302]	validation_0-mlogloss:0.71567
# [303]	validation_0-mlogloss:0.71564
# [304]	validation_0-mlogloss:0.71560
# [305]	validation_0-mlogloss:0.71560
# [306]	validation_0-mlogloss:0.71557
# [307]	validation_0-mlogloss:0.71556
# [308]	validation_0-mlogloss:0.71555
# [309]	validation_0-mlogloss:0.71553
# [310]	validation_0-mlogloss:0.71552
# [311]	validation_0-mlogloss:0.71551
# [312]	validation_0-mlogloss:0.71550
# [313]	validation_0-mlogloss:0.71548
# [314]	validation_0-mlogloss:0.71546
# [315]	validation_0-mlogloss:0.71543
# [316]	validation_0-mlogloss:0.71542
# [317]	validation_0-mlogloss:0.71539
# [318]	validation_0-mlogloss:0.71537
# [319]	validation_0-mlogloss:0.71536
# [320]	validation_0-mlogloss:0.71536
# [321]	validation_0-mlogloss:0.71535
# [322]	validation_0-mlogloss:0.71533
# [323]	validation_0-mlogloss:0.71531
# [324]	validation_0-mlogloss:0.71531
# [325]	validation_0-mlogloss:0.71529
# [326]	validation_0-mlogloss:0.71526
# [327]	validation_0-mlogloss:0.71525
# [328]	validation_0-mlogloss:0.71525
# [329]	validation_0-mlogloss:0.71523
# [330]	validation_0-mlogloss:0.71522
# [331]	validation_0-mlogloss:0.71520
# [332]	validation_0-mlogloss:0.71519
# [333]	validation_0-mlogloss:0.71519
# [334]	validation_0-mlogloss:0.71517
# [335]	validation_0-mlogloss:0.71517
# [336]	validation_0-mlogloss:0.71516
# [337]	validation_0-mlogloss:0.71514
# [338]	validation_0-mlogloss:0.71513
# [339]	validation_0-mlogloss:0.71513
# [340]	validation_0-mlogloss:0.71511
# [341]	validation_0-mlogloss:0.71510
# [342]	validation_0-mlogloss:0.71507
# [343]	validation_0-mlogloss:0.71506
# [344]	validation_0-mlogloss:0.71504
# [345]	validation_0-mlogloss:0.71503
# [346]	validation_0-mlogloss:0.71502
# [347]	validation_0-mlogloss:0.71500
# [348]	validation_0-mlogloss:0.71500
# [349]	validation_0-mlogloss:0.71500
# [350]	validation_0-mlogloss:0.71499
# [351]	validation_0-mlogloss:0.71499
# [352]	validation_0-mlogloss:0.71499
# [353]	validation_0-mlogloss:0.71498
# [354]	validation_0-mlogloss:0.71497
# [426]	validation_0-mlogloss:0.71479
# [427]	validation_0-mlogloss:0.71480
# [428]	validation_0-mlogloss:0.71479
# [429]	validation_0-mlogloss:0.71478
# [430]	validation_0-mlogloss:0.71479
# [431]	validation_0-mlogloss:0.71479
# [432]	validation_0-mlogloss:0.71478
# [433]	validation_0-mlogloss:0.71478
# [434]	validation_0-mlogloss:0.71477
# [435]	validation_0-mlogloss:0.71477
# [436]	validation_0-mlogloss:0.71479
# [437]	validation_0-mlogloss:0.71480
# [438]	validation_0-mlogloss:0.71481
# [439]	validation_0-mlogloss:0.71480
# [440]	validation_0-mlogloss:0.71479
# [441]	validation_0-mlogloss:0.71478
# [442]	validation_0-mlogloss:0.71478
# [443]	validation_0-mlogloss:0.71476
# [444]	validation_0-mlogloss:0.71475
# [445]	validation_0-mlogloss:0.71474
# [446]	validation_0-mlogloss:0.71474
# [447]	validation_0-mlogloss:0.71475
# [448]	validation_0-mlogloss:0.71477
# [449]	validation_0-mlogloss:0.71478
# [450]	validation_0-mlogloss:0.71480
# [451]	validation_0-mlogloss:0.71481
# [452]	validation_0-mlogloss:0.71480
# [453]	validation_0-mlogloss:0.71481
# [454]	validation_0-mlogloss:0.71480
# [455]	validation_0-mlogloss:0.71480
# [456]	validation_0-mlogloss:0.71480
# [457]	validation_0-mlogloss:0.71481
# [458]	validation_0-mlogloss:0.71481
# [459]	validation_0-mlogloss:0.71480
# [460]	validation_0-mlogloss:0.71479
# [461]	validation_0-mlogloss:0.71479
# [462]	validation_0-mlogloss:0.71480
# [463]	validation_0-mlogloss:0.71480
# [464]	validation_0-mlogloss:0.71481
# [465]	validation_0-mlogloss:0.71481
# [466]	validation_0-mlogloss:0.71482
# [467]	validation_0-mlogloss:0.71483
# [468]	validation_0-mlogloss:0.71482
# [469]	validation_0-mlogloss:0.71482
# [470]	validation_0-mlogloss:0.71482
# [471]	validation_0-mlogloss:0.71481
# [472]	validation_0-mlogloss:0.71480
# [473]	validation_0-mlogloss:0.71480
# [474]	validation_0-mlogloss:0.71481
# [475]	validation_0-mlogloss:0.71482
# [476]	validation_0-mlogloss:0.71481
# [477]	validation_0-mlogloss:0.71480
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          bad       0.60      0.72      0.65     10281
#         good       0.73      0.68      0.70     13708
#      neutral       0.83      0.69      0.76      7057
#
#     accuracy                           0.70     31046
#    macro avg       0.72      0.70      0.70     31046
# weighted avg       0.71      0.70      0.70     31046
#
#
# Weighted F1 Score: 0.6984
#
# Top 10 Most Important Features:
#                          feature  importance
# 65      received_date_is_weekend    0.253685
# 63       received_date_dayofweek    0.100221
# 71       Date_released_diff_days    0.071808
# 80  purchased_received_diff_days    0.051245
# 77    payment_received_diff_days    0.049675
# 85               discount_amount    0.042799
# 72      Date_estimated_diff_days    0.030205
# 73       Date_received_diff_days    0.025160
# 94                total_discount    0.017130
# 97                discount_range    0.011900
#
# Making predictions on test set...
#
# Submission file created successfully!
