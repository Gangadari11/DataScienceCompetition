# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, f1_score
import xgboost as xgb
from datetime import datetime

def prepare_data(df):
    """
    Enhanced data preparation with more feature engineering
    """
    # Create a copy to avoid modifying original data
    data = df.copy()
    
    # Fill missing values with appropriate strategies
    numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = data.select_dtypes(include=['object']).columns
    
    # Fill numeric columns with median
    for col in numeric_cols:
        data[col] = data[col].fillna(data[col].median())
    
    # Fill categorical columns with mode
    for col in categorical_cols:
        data[col] = data[col].fillna(data[col].mode()[0])
    
    # Convert date columns to datetime and extract features
    date_cols = ['Date_Registered', 'payment_datetime', 'purchased_datetime', 
                 'released_date', 'estimated_delivery_date', 'received_date']
    
    for col in date_cols:
        if col in data.columns:
            data[col] = pd.to_datetime(data[col], errors='coerce')
            # Extract numerical features from dates
            data[f'{col}_year'] = data[col].dt.year.fillna(-1).astype(int)
            data[f'{col}_month'] = data[col].dt.month.fillna(-1).astype(int)
            data[f'{col}_day'] = data[col].dt.day.fillna(-1).astype(int)
            data[f'{col}_dayofweek'] = data[col].dt.dayofweek.fillna(-1).astype(int)
            data[f'{col}_quarter'] = data[col].dt.quarter.fillna(-1).astype(int)
            data[f'{col}_is_weekend'] = (data[col].dt.dayofweek >= 5).astype(int)
    
    # Calculate time differences between dates
    if 'payment_datetime' in data.columns and 'purchased_datetime' in data.columns:
        data['payment_purchase_diff'] = (data['payment_datetime'] - data['purchased_datetime']).dt.total_seconds() / 3600
    
    if 'estimated_delivery_date' in data.columns and 'received_date' in data.columns:
        data['delivery_delay'] = (data['received_date'] - data['estimated_delivery_date']).dt.total_seconds() / (24*3600)
    
    # Drop original date columns
    for col in date_cols:
        if col in data.columns:
            data = data.drop(columns=[col])
    
    # Create price-related features
    if 'Product_value' in data.columns and 'final_payment' in data.columns:
        data['discount_amount'] = data['Product_value'] - data['final_payment']
        data['discount_percentage'] = (data['discount_amount'] / data['Product_value'] * 100).clip(0, 100)
        data['price_tier'] = pd.qcut(data['Product_value'], q=5, labels=[1,2,3,4,5], duplicates='drop')
    
    # Create loyalty-related features
    if 'loyalty_points_redeemed' in data.columns:
        data['has_redeemed_points'] = (data['loyalty_points_redeemed'] > 0).astype(int)
    
    # Aggregate discount features
    discount_cols = [col for col in data.columns if 'discount_percentage' in col]
    if discount_cols:
        data['total_discount'] = data[discount_cols].sum(axis=1)
    
    # Encode categorical variables
    categorical_cols = ['Gender', 'Is_current_loyalty_program_member', 'loyalty_tier',
                       'payment_method', 'purchase_medium', 'shipping_method',
                       'product_category']
    
    # Only encode categorical columns that exist in the dataset
    existing_cat_cols = [col for col in categorical_cols if col in data.columns]
    
    # Use LabelEncoder for categorical variables
    le_dict = {}
    for col in existing_cat_cols:
        le_dict[col] = LabelEncoder()
        data[col] = le_dict[col].fit_transform(data[col].astype(str))
    
    return data

# Load datasets
print("Loading datasets...")
train_data = pd.read_csv('train_dataset.csv')
test_data = pd.read_csv('test_dataset.csv')

print("\nTrain data shape:", train_data.shape)
print("Test data shape:", test_data.shape)

# Prepare features
print("\nPreparing features...")
X_train_full = prepare_data(train_data)
X_test = prepare_data(test_data)

# Remove non-feature columns from training data
cols_to_drop = ['customer_experience', 'user_id', 'transaction_id', 
                'order_id', 'tracking_number']
feature_cols = [col for col in X_train_full.columns 
                if col not in cols_to_drop]

X = X_train_full[feature_cols]
y = train_data['customer_experience']

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print("\nNumber of features:", len(feature_cols))

# Encode target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# Ensure test data has same columns as training data
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
X_test_scaled = scaler.transform(X_test)

# Optimized XGBoost parameters
params = {
    'n_estimators': 500,
    'max_depth': 8,
    'learning_rate': 0.01,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'min_child_weight': 3,
    'gamma': 0.1,
    'objective': 'multi:softprob',
    'eval_metric': 'mlogloss',
    'random_state': 42,
    'n_jobs': -1
}

# Initialize and train model
print("\nTraining XGBoost model...")
model = xgb.XGBClassifier(**params)

# Perform cross-validation
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='f1_weighted')
print(f"\nCross-validation F1 scores: {cv_scores}")
print(f"Mean CV F1 score: {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")

# Train final model
model.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# Make predictions on validation set
y_pred = model.predict(X_val)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=le.classes_))

# Calculate weighted F1 score
weighted_f1 = f1_score(y_val, y_pred, average='weighted')
print(f"\nWeighted F1 Score: {weighted_f1:.4f}")

# Feature importance analysis
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': model.feature_importances_
})
print("\nTop 10 Most Important Features:")
print(feature_importance.sort_values('importance', ascending=False).head(10))

# Make predictions on test set
print("\nMaking predictions on test set...")
test_predictions = model.predict(X_test_scaled)
test_predictions_labels = le.inverse_transform(test_predictions)

# Create submission file
submission = pd.DataFrame({
    'id': range(len(test_predictions_labels)),
    'customer_experience': test_predictions_labels
})

# Save submission file
submission.to_csv('submission4.csv', index=False)
print("\nSubmission file created successfully!")

# Verify file contents
print("\nVerifying saved submission file:")
saved_submission = pd.read_csv('submission4.csv')
print(saved_submission.head())
print("\nShape of saved submission:", saved_submission.shape)
# Out:
# Loading datasets...
#
# Train data shape: (206969, 26)
# Test data shape: (137971, 25)
#
# Preparing features...
#
# Number of features: 58
#
# Training XGBoost model...
#
# Cross-validation F1 scores: [0.65360323 0.64754644 0.64469681 0.63932008 0.64904806]
# Mean CV F1 score: 0.6468 (+/- 0.0095)
# [0]	validation_0-mlogloss:1.09588
# [1]	validation_0-mlogloss:1.09318
# [2]	validation_0-mlogloss:1.09016
# [3]	validation_0-mlogloss:1.08735
# [4]	validation_0-mlogloss:1.08469
# [5]	validation_0-mlogloss:1.08164
# [6]	validation_0-mlogloss:1.07888
# [7]	validation_0-mlogloss:1.07615
# [8]	validation_0-mlogloss:1.07333
# [9]	validation_0-mlogloss:1.07043
# [10]	validation_0-mlogloss:1.06756
# [11]	validation_0-mlogloss:1.06481
# [12]	validation_0-mlogloss:1.06256
# [13]	validation_0-mlogloss:1.06026
# [14]	validation_0-mlogloss:1.05801
# [15]	validation_0-mlogloss:1.05556
# [16]	validation_0-mlogloss:1.05298
# [17]	validation_0-mlogloss:1.05050
# [18]	validation_0-mlogloss:1.04839
# [19]	validation_0-mlogloss:1.04607
# [20]	validation_0-mlogloss:1.04388
# [21]	validation_0-mlogloss:1.04155
# [22]	validation_0-mlogloss:1.03897
# [23]	validation_0-mlogloss:1.03687
# [24]	validation_0-mlogloss:1.03456
# [25]	validation_0-mlogloss:1.03239
# [26]	validation_0-mlogloss:1.03016
# [27]	validation_0-mlogloss:1.02812
# [28]	validation_0-mlogloss:1.02600
# [29]	validation_0-mlogloss:1.02382
# [30]	validation_0-mlogloss:1.02198
# [31]	validation_0-mlogloss:1.01995
# [32]	validation_0-mlogloss:1.01780
# [33]	validation_0-mlogloss:1.01572
# [34]	validation_0-mlogloss:1.01396
# [35]	validation_0-mlogloss:1.01201
# [36]	validation_0-mlogloss:1.01025
# [37]	validation_0-mlogloss:1.00865
# [38]	validation_0-mlogloss:1.00660
# [39]	validation_0-mlogloss:1.00526
# [40]	validation_0-mlogloss:1.00374
# [41]	validation_0-mlogloss:1.00178
# [42]	validation_0-mlogloss:1.00054
# [43]	validation_0-mlogloss:0.99854
# [44]	validation_0-mlogloss:0.99694
# [45]	validation_0-mlogloss:0.99524
# [46]	validation_0-mlogloss:0.99366
# [47]	validation_0-mlogloss:0.99218
# [48]	validation_0-mlogloss:0.99065
# [49]	validation_0-mlogloss:0.98928
# [50]	validation_0-mlogloss:0.98788
# [51]	validation_0-mlogloss:0.98632
# [52]	validation_0-mlogloss:0.98493
# [53]	validation_0-mlogloss:0.98333
# [54]	validation_0-mlogloss:0.98155
# [55]	validation_0-mlogloss:0.97992
# [56]	validation_0-mlogloss:0.97838
# [57]	validation_0-mlogloss:0.97688
# [58]	validation_0-mlogloss:0.97552
# [59]	validation_0-mlogloss:0.97401
# [60]	validation_0-mlogloss:0.97249
# [61]	validation_0-mlogloss:0.97102
# [62]	validation_0-mlogloss:0.96954
# [63]	validation_0-mlogloss:0.96822
# [64]	validation_0-mlogloss:0.96695
# [65]	validation_0-mlogloss:0.96552
# [66]	validation_0-mlogloss:0.96400
# [67]	validation_0-mlogloss:0.96255
# [68]	validation_0-mlogloss:0.96112
# [69]	validation_0-mlogloss:0.96014
# [70]	validation_0-mlogloss:0.95885
# [71]	validation_0-mlogloss:0.95749
# [72]	validation_0-mlogloss:0.95616
# [73]	validation_0-mlogloss:0.95483
# [74]	validation_0-mlogloss:0.95350
# [75]	validation_0-mlogloss:0.95238
# [76]	validation_0-mlogloss:0.95139
# [77]	validation_0-mlogloss:0.95020
# [78]	validation_0-mlogloss:0.94895
# [79]	validation_0-mlogloss:0.94774
# [80]	validation_0-mlogloss:0.94659
# [81]	validation_0-mlogloss:0.94547
# [82]	validation_0-mlogloss:0.94444
# [83]	validation_0-mlogloss:0.94335
# [84]	validation_0-mlogloss:0.94222
# [85]	validation_0-mlogloss:0.94138
# [86]	validation_0-mlogloss:0.94030
# [87]	validation_0-mlogloss:0.93920
# [88]	validation_0-mlogloss:0.93808
# [89]	validation_0-mlogloss:0.93705
# [90]	validation_0-mlogloss:0.93597
# [91]	validation_0-mlogloss:0.93492
# [92]	validation_0-mlogloss:0.93390
# [93]	validation_0-mlogloss:0.93284
# [94]	validation_0-mlogloss:0.93204
# [95]	validation_0-mlogloss:0.93096
# [96]	validation_0-mlogloss:0.92996
# [97]	validation_0-mlogloss:0.92898
# [98]	validation_0-mlogloss:0.92823
# [99]	validation_0-mlogloss:0.92709
# [100]	validation_0-mlogloss:0.92617
# [101]	validation_0-mlogloss:0.92542
# [102]	validation_0-mlogloss:0.92445
# [103]	validation_0-mlogloss:0.92377
# [104]	validation_0-mlogloss:0.92278
# [105]	validation_0-mlogloss:0.92186
# [106]	validation_0-mlogloss:0.92099
# [107]	validation_0-mlogloss:0.92015
# [108]	validation_0-mlogloss:0.91919
# [109]	validation_0-mlogloss:0.91827
# [110]	validation_0-mlogloss:0.91732
# [111]	validation_0-mlogloss:0.91644
# [112]	validation_0-mlogloss:0.91550
# [113]	validation_0-mlogloss:0.91462
# [114]	validation_0-mlogloss:0.91397
# [115]	validation_0-mlogloss:0.91337
# [116]	validation_0-mlogloss:0.91257
# [117]	validation_0-mlogloss:0.91175
# [118]	validation_0-mlogloss:0.91090
# [119]	validation_0-mlogloss:0.91006
# [120]	validation_0-mlogloss:0.90920
# [121]	validation_0-mlogloss:0.90843
# [122]	validation_0-mlogloss:0.90777
# [123]	validation_0-mlogloss:0.90700
# [124]	validation_0-mlogloss:0.90628
# [125]	validation_0-mlogloss:0.90555
# [126]	validation_0-mlogloss:0.90491
# [127]	validation_0-mlogloss:0.90418
# [128]	validation_0-mlogloss:0.90357
# [129]	validation_0-mlogloss:0.90282
# [130]	validation_0-mlogloss:0.90203
# [131]	validation_0-mlogloss:0.90148
# [132]	validation_0-mlogloss:0.90079
# [133]	validation_0-mlogloss:0.89995
# [134]	validation_0-mlogloss:0.89929
# [135]	validation_0-mlogloss:0.89870
# [136]	validation_0-mlogloss:0.89791
# [137]	validation_0-mlogloss:0.89718
# [138]	validation_0-mlogloss:0.89646
# [139]	validation_0-mlogloss:0.89587
# [140]	validation_0-mlogloss:0.89521
# [141]	validation_0-mlogloss:0.89459
# [142]	validation_0-mlogloss:0.89393
# [143]	validation_0-mlogloss:0.89332
# [144]	validation_0-mlogloss:0.89289
# [145]	validation_0-mlogloss:0.89241
# [146]	validation_0-mlogloss:0.89177
# [147]	validation_0-mlogloss:0.89122
# [148]	validation_0-mlogloss:0.89060
# [149]	validation_0-mlogloss:0.88997
# [150]	validation_0-mlogloss:0.88937
# [151]	validation_0-mlogloss:0.88889
# [152]	validation_0-mlogloss:0.88839
# [153]	validation_0-mlogloss:0.88785
# [154]	validation_0-mlogloss:0.88742
# [155]	validation_0-mlogloss:0.88687
# [156]	validation_0-mlogloss:0.88638
# [157]	validation_0-mlogloss:0.88585
# [158]	validation_0-mlogloss:0.88528
# [159]	validation_0-mlogloss:0.88474
# [160]	validation_0-mlogloss:0.88416
# [161]	validation_0-mlogloss:0.88355
# [162]	validation_0-mlogloss:0.88304
# [163]	validation_0-mlogloss:0.88262
# [164]	validation_0-mlogloss:0.88214
# [165]	validation_0-mlogloss:0.88177
# [166]	validation_0-mlogloss:0.88128
# [167]	validation_0-mlogloss:0.88079
# [168]	validation_0-mlogloss:0.88030
# [169]	validation_0-mlogloss:0.87978
# [170]	validation_0-mlogloss:0.87938
# [171]	validation_0-mlogloss:0.87895
# [172]	validation_0-mlogloss:0.87845
# [173]	validation_0-mlogloss:0.87793
# [174]	validation_0-mlogloss:0.87739
# [175]	validation_0-mlogloss:0.87693
# [176]	validation_0-mlogloss:0.87654
# [177]	validation_0-mlogloss:0.87608
# [178]	validation_0-mlogloss:0.87558
# [179]	validation_0-mlogloss:0.87509
# [180]	validation_0-mlogloss:0.87465
# [181]	validation_0-mlogloss:0.87421
# [182]	validation_0-mlogloss:0.87378
# [183]	validation_0-mlogloss:0.87336
# [184]	validation_0-mlogloss:0.87293
# [185]	validation_0-mlogloss:0.87255
# [186]	validation_0-mlogloss:0.87222
# [187]	validation_0-mlogloss:0.87192
# [188]	validation_0-mlogloss:0.87148
# [189]	validation_0-mlogloss:0.87115
# [190]	validation_0-mlogloss:0.87078
# [191]	validation_0-mlogloss:0.87039
# [192]	validation_0-mlogloss:0.86998
# [193]	validation_0-mlogloss:0.86952
# [194]	validation_0-mlogloss:0.86913
# [195]	validation_0-mlogloss:0.86881
# [196]	validation_0-mlogloss:0.86843
# [197]	validation_0-mlogloss:0.86809
# [198]	validation_0-mlogloss:0.86772
# [199]	validation_0-mlogloss:0.86738
# [200]	validation_0-mlogloss:0.86702
# [201]	validation_0-mlogloss:0.86655
# [202]	validation_0-mlogloss:0.86625
# [203]	validation_0-mlogloss:0.86586
# [204]	validation_0-mlogloss:0.86546
# [205]	validation_0-mlogloss:0.86523
# [206]	validation_0-mlogloss:0.86494
# [207]	validation_0-mlogloss:0.86456
# [208]	validation_0-mlogloss:0.86427
# [209]	validation_0-mlogloss:0.86391
# [210]	validation_0-mlogloss:0.86359
# [211]	validation_0-mlogloss:0.86324
# [212]	validation_0-mlogloss:0.86288
# [213]	validation_0-mlogloss:0.86251
# [214]	validation_0-mlogloss:0.86217
# [215]	validation_0-mlogloss:0.86188
# [216]	validation_0-mlogloss:0.86155
# [217]	validation_0-mlogloss:0.86116
# [218]	validation_0-mlogloss:0.86083
# [219]	validation_0-mlogloss:0.86040
# [220]	validation_0-mlogloss:0.86011
# [221]	validation_0-mlogloss:0.85967
# [222]	validation_0-mlogloss:0.85937
# [223]	validation_0-mlogloss:0.85905
# [224]	validation_0-mlogloss:0.85874
# [225]	validation_0-mlogloss:0.85856
# [226]	validation_0-mlogloss:0.85826
# [227]	validation_0-mlogloss:0.85801
# [228]	validation_0-mlogloss:0.85774
# [229]	validation_0-mlogloss:0.85738
# [230]	validation_0-mlogloss:0.85708
# [231]	validation_0-mlogloss:0.85681
# [232]	validation_0-mlogloss:0.85651
# [233]	validation_0-mlogloss:0.85632
# [234]	validation_0-mlogloss:0.85595
# [235]	validation_0-mlogloss:0.85570
# [236]	validation_0-mlogloss:0.85539
# [237]	validation_0-mlogloss:0.85514
# [238]	validation_0-mlogloss:0.85483
# [239]	validation_0-mlogloss:0.85453
# [240]	validation_0-mlogloss:0.85427
# [241]	validation_0-mlogloss:0.85401
# [242]	validation_0-mlogloss:0.85378
# [243]	validation_0-mlogloss:0.85353
# [244]	validation_0-mlogloss:0.85324
# [245]	validation_0-mlogloss:0.85300
# [246]	validation_0-mlogloss:0.85274
# [247]	validation_0-mlogloss:0.85255
# [248]	validation_0-mlogloss:0.85229
# [249]	validation_0-mlogloss:0.85216
# [250]	validation_0-mlogloss:0.85183
# [251]	validation_0-mlogloss:0.85161
# [252]	validation_0-mlogloss:0.85132
# [253]	validation_0-mlogloss:0.85106
# [254]	validation_0-mlogloss:0.85089
# [255]	validation_0-mlogloss:0.85062
# [256]	validation_0-mlogloss:0.85036
# [257]	validation_0-mlogloss:0.85007
# [258]	validation_0-mlogloss:0.84982
# [259]	validation_0-mlogloss:0.84963
# [260]	validation_0-mlogloss:0.84939
# [261]	validation_0-mlogloss:0.84919
# [262]	validation_0-mlogloss:0.84895
# [263]	validation_0-mlogloss:0.84867
# [264]	validation_0-mlogloss:0.84846
# [265]	validation_0-mlogloss:0.84822
# [266]	validation_0-mlogloss:0.84805
# [267]	validation_0-mlogloss:0.84780
# [268]	validation_0-mlogloss:0.84762
# [269]	validation_0-mlogloss:0.84738
# [270]	validation_0-mlogloss:0.84722
# [271]	validation_0-mlogloss:0.84699
# [272]	validation_0-mlogloss:0.84677
# [273]	validation_0-mlogloss:0.84656
# [274]	validation_0-mlogloss:0.84628
# [275]	validation_0-mlogloss:0.84605
# [276]	validation_0-mlogloss:0.84585
# [277]	validation_0-mlogloss:0.84564
# [278]	validation_0-mlogloss:0.84540
# [279]	validation_0-mlogloss:0.84515
# [280]	validation_0-mlogloss:0.84496
# [281]	validation_0-mlogloss:0.84478
# [282]	validation_0-mlogloss:0.84456
# [283]	validation_0-mlogloss:0.84428
# [284]	validation_0-mlogloss:0.84416
# [285]	validation_0-mlogloss:0.84388
# [286]	validation_0-mlogloss:0.84365
# [287]	validation_0-mlogloss:0.84343
# [288]	validation_0-mlogloss:0.84323
# [289]	validation_0-mlogloss:0.84304
# [290]	validation_0-mlogloss:0.84282
# [291]	validation_0-mlogloss:0.84252
# [292]	validation_0-mlogloss:0.84231
# [293]	validation_0-mlogloss:0.84201
# [294]	validation_0-mlogloss:0.84182
# [295]	validation_0-mlogloss:0.84158
# [296]	validation_0-mlogloss:0.84141
# [297]	validation_0-mlogloss:0.84121
# [298]	validation_0-mlogloss:0.84107
# [299]	validation_0-mlogloss:0.84086
# [300]	validation_0-mlogloss:0.84062
# [301]	validation_0-mlogloss:0.84053
# [302]	validation_0-mlogloss:0.84025
# [303]	validation_0-mlogloss:0.84015
# [304]	validation_0-mlogloss:0.83996
# [305]	validation_0-mlogloss:0.83978
# [306]	validation_0-mlogloss:0.83955
# [307]	validation_0-mlogloss:0.83932
# [308]	validation_0-mlogloss:0.83915
# [309]	validation_0-mlogloss:0.83906
# [310]	validation_0-mlogloss:0.83881
# [311]	validation_0-mlogloss:0.83863
# [312]	validation_0-mlogloss:0.83845
# [313]	validation_0-mlogloss:0.83818
# [314]	validation_0-mlogloss:0.83791
# [315]	validation_0-mlogloss:0.83774
# [316]	validation_0-mlogloss:0.83756
# [317]	validation_0-mlogloss:0.83738
# [318]	validation_0-mlogloss:0.83721
# [319]	validation_0-mlogloss:0.83709
# [320]	validation_0-mlogloss:0.83692
# [321]	validation_0-mlogloss:0.83677
# [322]	validation_0-mlogloss:0.83660
# [323]	validation_0-mlogloss:0.83644
# [324]	validation_0-mlogloss:0.83624
# [325]	validation_0-mlogloss:0.83605
# [326]	validation_0-mlogloss:0.83590
# [327]	validation_0-mlogloss:0.83571
# [328]	validation_0-mlogloss:0.83549
# [329]	validation_0-mlogloss:0.83537
# [330]	validation_0-mlogloss:0.83521
# [331]	validation_0-mlogloss:0.83504
# [332]	validation_0-mlogloss:0.83496
# [333]	validation_0-mlogloss:0.83481
# [334]	validation_0-mlogloss:0.83468
# [335]	validation_0-mlogloss:0.83449
# [336]	validation_0-mlogloss:0.83435
# [337]	validation_0-mlogloss:0.83417
# [338]	validation_0-mlogloss:0.83405
# [339]	validation_0-mlogloss:0.83392
# [340]	validation_0-mlogloss:0.83381
# [341]	validation_0-mlogloss:0.83368
# [342]	validation_0-mlogloss:0.83360
# [343]	validation_0-mlogloss:0.83349
# [344]	validation_0-mlogloss:0.83337
# [345]	validation_0-mlogloss:0.83320
# [346]	validation_0-mlogloss:0.83304
# [347]	validation_0-mlogloss:0.83291
# [348]	validation_0-mlogloss:0.83267
# [349]	validation_0-mlogloss:0.83254
# [350]	validation_0-mlogloss:0.83243
# [351]	validation_0-mlogloss:0.83232
# [352]	validation_0-mlogloss:0.83215
# [353]	validation_0-mlogloss:0.83201
# [354]	validation_0-mlogloss:0.83184
# [355]	validation_0-mlogloss:0.83171
# [356]	validation_0-mlogloss:0.83162
# [357]	validation_0-mlogloss:0.83148
# [358]	validation_0-mlogloss:0.83137
# [359]	validation_0-mlogloss:0.83124
# [360]	validation_0-mlogloss:0.83114
# [361]	validation_0-mlogloss:0.83103
# [362]	validation_0-mlogloss:0.83087
# [363]	validation_0-mlogloss:0.83074
# [364]	validation_0-mlogloss:0.83061
# [365]	validation_0-mlogloss:0.83047
# [366]	validation_0-mlogloss:0.83032
# [367]	validation_0-mlogloss:0.83021
# [368]	validation_0-mlogloss:0.83006
# [369]	validation_0-mlogloss:0.82995
# [370]	validation_0-mlogloss:0.82985
# [371]	validation_0-mlogloss:0.82972
# [372]	validation_0-mlogloss:0.82965
# [373]	validation_0-mlogloss:0.82955
# [374]	validation_0-mlogloss:0.82946
# [375]	validation_0-mlogloss:0.82933
# [376]	validation_0-mlogloss:0.82920
# [377]	validation_0-mlogloss:0.82907
# [378]	validation_0-mlogloss:0.82901
# [379]	validation_0-mlogloss:0.82891
# [380]	validation_0-mlogloss:0.82880
# [381]	validation_0-mlogloss:0.82869
# [382]	validation_0-mlogloss:0.82854
# [383]	validation_0-mlogloss:0.82835
# [384]	validation_0-mlogloss:0.82825
# [385]	validation_0-mlogloss:0.82813
# [386]	validation_0-mlogloss:0.82803
# [387]	validation_0-mlogloss:0.82794
# [388]	validation_0-mlogloss:0.82786
# [389]	validation_0-mlogloss:0.82777
# [390]	validation_0-mlogloss:0.82762
# [391]	validation_0-mlogloss:0.82753
# [392]	validation_0-mlogloss:0.82740
# [393]	validation_0-mlogloss:0.82727
# [394]	validation_0-mlogloss:0.82713
# [395]	validation_0-mlogloss:0.82702
# [396]	validation_0-mlogloss:0.82691
# [397]	validation_0-mlogloss:0.82681
# [398]	validation_0-mlogloss:0.82670
# [399]	validation_0-mlogloss:0.82657
# [400]	validation_0-mlogloss:0.82648
# [401]	validation_0-mlogloss:0.82639
# [402]	validation_0-mlogloss:0.82629
# [403]	validation_0-mlogloss:0.82621
# [404]	validation_0-mlogloss:0.82610
# [405]	validation_0-mlogloss:0.82604
# [406]	validation_0-mlogloss:0.82593
# [407]	validation_0-mlogloss:0.82584
# [408]	validation_0-mlogloss:0.82575
# [409]	validation_0-mlogloss:0.82558
# [410]	validation_0-mlogloss:0.82553
# [411]	validation_0-mlogloss:0.82545
# [412]	validation_0-mlogloss:0.82537
# [413]	validation_0-mlogloss:0.82520
# [414]	validation_0-mlogloss:0.82512
# [415]	validation_0-mlogloss:0.82504
# [416]	validation_0-mlogloss:0.82493
# [417]	validation_0-mlogloss:0.82488
# [418]	validation_0-mlogloss:0.82483
# [419]	validation_0-mlogloss:0.82471
# [420]	validation_0-mlogloss:0.82463
# [421]	validation_0-mlogloss:0.82453
# [422]	validation_0-mlogloss:0.82446
# [423]	validation_0-mlogloss:0.82436
# [424]	validation_0-mlogloss:0.82423
# [425]	validation_0-mlogloss:0.82411
# [426]	validation_0-mlogloss:0.82407
# [427]	validation_0-mlogloss:0.82399
# [428]	validation_0-mlogloss:0.82388
# [429]	validation_0-mlogloss:0.82382
# [430]	validation_0-mlogloss:0.82369
# [431]	validation_0-mlogloss:0.82351
# [432]	validation_0-mlogloss:0.82342
# [433]	validation_0-mlogloss:0.82332
# [434]	validation_0-mlogloss:0.82326
# [435]	validation_0-mlogloss:0.82313
# [436]	validation_0-mlogloss:0.82301
# [437]	validation_0-mlogloss:0.82287
# [438]	validation_0-mlogloss:0.82279
# [439]	validation_0-mlogloss:0.82263
# [440]	validation_0-mlogloss:0.82252
# [441]	validation_0-mlogloss:0.82248
# [442]	validation_0-mlogloss:0.82243
# [443]	validation_0-mlogloss:0.82233
# [444]	validation_0-mlogloss:0.82220
# [445]	validation_0-mlogloss:0.82212
# [446]	validation_0-mlogloss:0.82203
# [447]	validation_0-mlogloss:0.82199
# [448]	validation_0-mlogloss:0.82193
# [449]	validation_0-mlogloss:0.82184
# [450]	validation_0-mlogloss:0.82170
# [451]	validation_0-mlogloss:0.82164
# [452]	validation_0-mlogloss:0.82158
# [453]	validation_0-mlogloss:0.82150
# [454]	validation_0-mlogloss:0.82142
# [455]	validation_0-mlogloss:0.82129
# [456]	validation_0-mlogloss:0.82120
# [457]	validation_0-mlogloss:0.82113
# [458]	validation_0-mlogloss:0.82099
# [459]	validation_0-mlogloss:0.82095
# [460]	validation_0-mlogloss:0.82084
# [461]	validation_0-mlogloss:0.82073
# [462]	validation_0-mlogloss:0.82067
# [463]	validation_0-mlogloss:0.82058
# [464]	validation_0-mlogloss:0.82049
# [465]	validation_0-mlogloss:0.82044
# [466]	validation_0-mlogloss:0.82034
# [467]	validation_0-mlogloss:0.82020
# [468]	validation_0-mlogloss:0.82013
# [469]	validation_0-mlogloss:0.82000
# [470]	validation_0-mlogloss:0.81992
# [471]	validation_0-mlogloss:0.81982
# [472]	validation_0-mlogloss:0.81974
# [473]	validation_0-mlogloss:0.81965
# [474]	validation_0-mlogloss:0.81954
# [475]	validation_0-mlogloss:0.81946
# [476]	validation_0-mlogloss:0.81938
# [477]	validation_0-mlogloss:0.81933
# [478]	validation_0-mlogloss:0.81921
# [479]	validation_0-mlogloss:0.81902
# [480]	validation_0-mlogloss:0.81890
# [481]	validation_0-mlogloss:0.81884
# [482]	validation_0-mlogloss:0.81873
# [483]	validation_0-mlogloss:0.81865
# [484]	validation_0-mlogloss:0.81851
# [485]	validation_0-mlogloss:0.81842
# [486]	validation_0-mlogloss:0.81827
# [487]	validation_0-mlogloss:0.81822
# [488]	validation_0-mlogloss:0.81815
# [489]	validation_0-mlogloss:0.81809
# [490]	validation_0-mlogloss:0.81807
# [491]	validation_0-mlogloss:0.81797
# [492]	validation_0-mlogloss:0.81792
# [493]	validation_0-mlogloss:0.81784
# [494]	validation_0-mlogloss:0.81782
# [495]	validation_0-mlogloss:0.81772
# [496]	validation_0-mlogloss:0.81764
# [497]	validation_0-mlogloss:0.81759
# [498]	validation_0-mlogloss:0.81755
# [499]	validation_0-mlogloss:0.81751
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          bad       0.57      0.65      0.60     13708
#         good       0.71      0.67      0.69     18278
#      neutral       0.66      0.61      0.63      9408
#
#     accuracy                           0.65     41394
#    macro avg       0.65      0.64      0.64     41394
# weighted avg       0.65      0.65      0.65     41394
#
#
# Weighted F1 Score: 0.6478
#
# Top 10 Most Important Features:
#                          feature  importance
# 50      received_date_is_weekend    0.339878
# 48       received_date_dayofweek    0.088303
# 21         payment_datetime_year    0.056931
# 27       purchased_datetime_year    0.049957
# 53               discount_amount    0.039724
# 15          Date_Registered_year    0.038333
# 52                delivery_delay    0.021389
# 57                total_discount    0.021135
# 0                             id    0.017772
# 39  estimated_delivery_date_year    0.017671
#
# Making predictions on test set...
#
# Submission file created successfully!
#
# Verifying saved submission file:
#    id customer_experience
# 0   0                 bad
# 1   1                 bad
# 2   2                good
# 3   3                 bad
# 4   4                 bad
#
# Shape of saved submission: (137971, 2)
