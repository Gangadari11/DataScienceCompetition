# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler, PowerTransformer
from sklearn.metrics import classification_report, f1_score
import xgboost as xgb
from datetime import datetime
from sklearn.decomposition import PCA

def prepare_data(df):
    """
    Enhanced data preparation with advanced feature engineering
    """
    # Create a copy to avoid modifying original data
    data = df.copy()
    
    # Fill missing values with appropriate strategies
    numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = data.select_dtypes(include=['object']).columns
    
    # Fill numeric columns with median
    for col in numeric_cols:
        data[col] = data[col].fillna(data[col].median())
    
    # Fill categorical columns with mode
    for col in categorical_cols:
        data[col] = data[col].fillna(data[col].mode()[0])
    
    # Convert date columns to datetime and extract features
    date_cols = ['Date_Registered', 'payment_datetime', 'purchased_datetime', 
                 'released_date', 'estimated_delivery_date', 'received_date']
    
    for col in date_cols:
        if col in data.columns:
            data[col] = pd.to_datetime(data[col], errors='coerce')
            # Extract numerical features from dates
            data[f'{col}_year'] = data[col].dt.year.fillna(-1).astype(int)
            data[f'{col}_month'] = data[col].dt.month.fillna(-1).astype(int)
            data[f'{col}_day'] = data[col].dt.day.fillna(-1).astype(int)
            data[f'{col}_dayofweek'] = data[col].dt.dayofweek.fillna(-1).astype(int)
            data[f'{col}_quarter'] = data[col].dt.quarter.fillna(-1).astype(int)
            data[f'{col}_is_weekend'] = (data[col].dt.dayofweek >= 5).astype(int)
            data[f'{col}_is_month_end'] = (data[col].dt.is_month_end).astype(int)
            data[f'{col}_is_month_start'] = (data[col].dt.is_month_start).astype(int)
            data[f'{col}_hour'] = data[col].dt.hour.fillna(-1).astype(int)
    
    # Calculate time differences between all date pairs
    date_cols_dt = [col for col in date_cols if col in data.columns]
    for i in range(len(date_cols_dt)):
        for j in range(i + 1, len(date_cols_dt)):
            col1, col2 = date_cols_dt[i], date_cols_dt[j]
            diff_name = f'{col1.split("_")[0]}_{col2.split("_")[0]}_diff_days'
            data[diff_name] = (data[col2] - data[col1]).dt.total_seconds() / (24*3600)
    
    # Drop original date columns
    for col in date_cols:
        if col in data.columns:
            data = data.drop(columns=[col])
    
    # Create price-related features
    if 'Product_value' in data.columns and 'final_payment' in data.columns:
        data['price_per_loyalty_point'] = data['Product_value'] / (data['loyalty_points_redeemed'].clip(1))

        data['discount_amount'] = data['Product_value'] - data['final_payment']
        data['discount_percentage'] = (data['discount_amount'] / data['Product_value'] * 100).clip(0, 100)
        data['price_tier'] = pd.qcut(data['Product_value'], q=10, labels=False, duplicates='drop')
        data['price_to_loyalty_ratio'] = data['Product_value'] / (data['loyalty_points_redeemed'] + 1)
        
        # Log transform price features
        data['log_product_value'] = np.log1p(data['Product_value'])
        data['log_final_payment'] = np.log1p(data['final_payment'])
    
    # Enhanced loyalty features
    if 'loyalty_points_redeemed' in data.columns:
        data['has_redeemed_points'] = (data['loyalty_points_redeemed'] > 0).astype(int)
        data['log_loyalty_points'] = np.log1p(data['loyalty_points_redeemed'])
        data['points_to_value_ratio'] = data['loyalty_points_redeemed'] / (data['Product_value'] + 1)
    
    # Aggregate discount features
    discount_cols = [col for col in data.columns if 'discount_percentage' in col]
    if discount_cols:
        data['total_discount'] = data[discount_cols].sum(axis=1)
        data['max_discount'] = data[discount_cols].max(axis=1)
        data['min_discount'] = data[discount_cols].min(axis=1)
        data['discount_range'] = data['max_discount'] - data['min_discount']
    
    # Interaction features
    if 'loyalty_tier' in data.columns:
        data['loyalty_tier'] = data['loyalty_tier'].astype(str)
        data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
        data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
    
    # Encode categorical variables with target encoding
    categorical_cols = ['Gender', 'Is_current_loyalty_program_member', 'loyalty_tier',
                       'payment_method', 'purchase_medium', 'shipping_method',
                       'product_category']
    
    # Only encode categorical columns that exist in the dataset
    existing_cat_cols = [col for col in categorical_cols if col in data.columns]
    
    # Use LabelEncoder for categorical variables
    le_dict = {}
    for col in existing_cat_cols:
        le_dict[col] = LabelEncoder()
        data[col] = le_dict[col].fit_transform(data[col].astype(str))
        
    return data

# Load datasets
print("Loading datasets...")
train_data = pd.read_csv('train_dataset.csv')
test_data = pd.read_csv('test_dataset.csv')

print("\nTrain data shape:", train_data.shape)
print("Test data shape:", test_data.shape)

# Prepare features
print("\nPreparing features...")
X_train_full = prepare_data(train_data)
X_test = prepare_data(test_data)

# Remove non-feature columns from training data
cols_to_drop = ['customer_experience', 'user_id', 'transaction_id', 
                'order_id', 'tracking_number']
feature_cols = [col for col in X_train_full.columns 
                if col not in cols_to_drop]

X = X_train_full[feature_cols]
y = train_data['customer_experience']

# Scale numerical features and apply power transform
numeric_features = X.select_dtypes(include=['float64', 'int64']).columns
scaler = StandardScaler()
power = PowerTransformer(method='yeo-johnson')

X_numeric = X[numeric_features]
X_numeric_scaled = scaler.fit_transform(X_numeric)
X_numeric_transformed = power.fit_transform(X_numeric_scaled)
X[numeric_features] = X_numeric_transformed

# Add PCA features
pca = PCA(n_components=10)
pca_features = pca.fit_transform(X_numeric_transformed)
for i in range(pca_features.shape[1]):
    X[f'pca_feature_{i}'] = pca_features[:, i]

print("\nNumber of features:", len(X.columns))

# Encode target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.15,  # changed from 0.2
    random_state=42, 
    stratify=y
)

# Prepare test data
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
X_test_numeric = X_test[numeric_features]
X_test_numeric_scaled = scaler.transform(X_test_numeric)
X_test_numeric_transformed = power.transform(X_test_numeric_scaled)
X_test[numeric_features] = X_test_numeric_transformed

# Add PCA features to test data
test_pca_features = pca.transform(X_test_numeric_transformed)
for i in range(test_pca_features.shape[1]):
    X_test[f'pca_feature_{i}'] = test_pca_features[:, i]

# Optimized XGBoost parameters
params = {
    'n_estimators': 2000,  # keep same
    'max_depth': 10,        # increased from 7
    'learning_rate': 0.03,  # increased from 0.01
    'subsample': 1,      # increased from 0.8
    'colsample_bytree': 1,  # increased from 0.8
    'min_child_weight': 0.5,    # decreased from 3
    'gamma': 0.02,           # decreased from 0.1
    'alpha': 0.02,           # decreased from 0.1
    'lambda': 0.5,           # decreased from 1
    'objective': 'multi:softprob',
    'eval_metric': 'mlogloss',
    'random_state': 42,
    'n_jobs': -1,
    'tree_method': 'hist',
    'early_stopping_rounds': 25,  # increased from 10
    'grow_policy': 'lossguide'    # added this
}

# Initialize and train model with StratifiedKFold
print("\nTraining XGBoost model with cross-validation...")
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
cv_scores = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_train, y_train), 1):
    X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_fold_train, y_fold_val = y_train[train_idx], y_train[val_idx]
    
    fold_model = xgb.XGBClassifier(**params)
    fold_model.fit(
        X_fold_train, y_fold_train,
        eval_set=[(X_fold_val, y_fold_val)],
        verbose=False
    )
    
    fold_pred = fold_model.predict(X_fold_val)
    fold_score = f1_score(y_fold_val, fold_pred, average='weighted')
    cv_scores.append(fold_score)
    print(f"Fold {fold} F1 Score: {fold_score:.4f}")

print(f"\nMean CV F1 score: {np.mean(cv_scores):.4f} (+/- {np.std(cv_scores) * 2:.4f})")

# Train final model on full training data
print("\nTraining final model...")
final_model = xgb.XGBClassifier(**params)
final_model.fit(X_train, y_train, eval_set=[(X_val, y_val)])

# Make predictions on validation set
y_pred = final_model.predict(X_val)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=le.classes_))

# Calculate weighted F1 score
weighted_f1 = f1_score(y_val, y_pred, average='weighted')
print(f"\nWeighted F1 Score: {weighted_f1:.4f}")

# Feature importance analysis
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': final_model.feature_importances_
})
print("\nTop 10 Most Important Features:")
print(feature_importance.sort_values('importance', ascending=False).head(10))

# Make predictions on test set
print("\nMaking predictions on test set...")
test_predictions = final_model.predict(X_test)
test_predictions_labels = le.inverse_transform(test_predictions)

# Create submission file
submission = pd.DataFrame({
    'id': range(len(test_predictions_labels)),
    'customer_experience': test_predictions_labels
})

# Save submission file
submission.to_csv('submission18.csv', index=False)
print("\nSubmission file created successfully!")
# Out:
# Loading datasets...
#
# Train data shape: (206969, 26)
# Test data shape: (137971, 25)
#
# Preparing features...
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['max_discount'] = data[discount_cols].max(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['min_discount'] = data[discount_cols].min(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['discount_range'] = data['max_discount'] - data['min_discount']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['min_discount'] = data[discount_cols].min(axis=1)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['discount_range'] = data['max_discount'] - data['min_discount']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['loyalty_tier_num'] = LabelEncoder().fit_transform(data['loyalty_tier'])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['tier_price_interaction'] = data['loyalty_tier_num'] * data['Product_value']
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numeric_features] = X_numeric_transformed
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12356\255113284.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f'pca_feature_{i}'] = pca_features[:, i]
# Number of features: 110
#
# Training XGBoost model with cross-validation...
# Fold 1 F1 Score: 0.6950
# Fold 2 F1 Score: 0.6936
# Fold 3 F1 Score: 0.6916
# Fold 4 F1 Score: 0.6921
# Fold 5 F1 Score: 0.6959
#
# Mean CV F1 score: 0.6936 (+/- 0.0033)
#
# Training final model...
# [0]	validation_0-mlogloss:1.08286
# [1]	validation_0-mlogloss:1.06784
# [2]	validation_0-mlogloss:1.05356
# [3]	validation_0-mlogloss:1.03996
# [4]	validation_0-mlogloss:1.02700
# [5]	validation_0-mlogloss:1.01464
# [6]	validation_0-mlogloss:1.00287
# [7]	validation_0-mlogloss:0.99159
# [8]	validation_0-mlogloss:0.98085
# [9]	validation_0-mlogloss:0.97056
# [10]	validation_0-mlogloss:0.96073
# [11]	validation_0-mlogloss:0.95133
# [12]	validation_0-mlogloss:0.94233
# [13]	validation_0-mlogloss:0.93372
# [14]	validation_0-mlogloss:0.92550
# [15]	validation_0-mlogloss:0.91759
# [16]	validation_0-mlogloss:0.91002
# [17]	validation_0-mlogloss:0.90275
# [18]	validation_0-mlogloss:0.89581
# [19]	validation_0-mlogloss:0.88913
# [20]	validation_0-mlogloss:0.88274
# [21]	validation_0-mlogloss:0.87657
# [22]	validation_0-mlogloss:0.87068
# [23]	validation_0-mlogloss:0.86503
# [24]	validation_0-mlogloss:0.85956
# [25]	validation_0-mlogloss:0.85437
# [26]	validation_0-mlogloss:0.84940
# [27]	validation_0-mlogloss:0.84459
# [28]	validation_0-mlogloss:0.83999
# [29]	validation_0-mlogloss:0.83556
# [30]	validation_0-mlogloss:0.83131
# [31]	validation_0-mlogloss:0.82718
# [32]	validation_0-mlogloss:0.82326
# [33]	validation_0-mlogloss:0.81952
# [34]	validation_0-mlogloss:0.81590
# [35]	validation_0-mlogloss:0.81242
# [36]	validation_0-mlogloss:0.80910
# [37]	validation_0-mlogloss:0.80587
# [38]	validation_0-mlogloss:0.80278
# [39]	validation_0-mlogloss:0.79977
# [40]	validation_0-mlogloss:0.79690
# [41]	validation_0-mlogloss:0.79411
# [42]	validation_0-mlogloss:0.79142
# [43]	validation_0-mlogloss:0.78883
# [44]	validation_0-mlogloss:0.78636
# [45]	validation_0-mlogloss:0.78397
# [46]	validation_0-mlogloss:0.78167
# [47]	validation_0-mlogloss:0.77944
# [48]	validation_0-mlogloss:0.77732
# [49]	validation_0-mlogloss:0.77527
# [50]	validation_0-mlogloss:0.77324
# [51]	validation_0-mlogloss:0.77131
# [52]	validation_0-mlogloss:0.76949
# [53]	validation_0-mlogloss:0.76773
# [54]	validation_0-mlogloss:0.76604
# [55]	validation_0-mlogloss:0.76439
# [56]	validation_0-mlogloss:0.76281
# [57]	validation_0-mlogloss:0.76126
# [58]	validation_0-mlogloss:0.75978
# [59]	validation_0-mlogloss:0.75835
# [60]	validation_0-mlogloss:0.75698
# [61]	validation_0-mlogloss:0.75563
# [62]	validation_0-mlogloss:0.75439
# [63]	validation_0-mlogloss:0.75317
# [64]	validation_0-mlogloss:0.75199
# [65]	validation_0-mlogloss:0.75087
# [66]	validation_0-mlogloss:0.74979
# [67]	validation_0-mlogloss:0.74874
# [68]	validation_0-mlogloss:0.74772
# [69]	validation_0-mlogloss:0.74673
# [70]	validation_0-mlogloss:0.74576
# [71]	validation_0-mlogloss:0.74482
# [72]	validation_0-mlogloss:0.74392
# [73]	validation_0-mlogloss:0.74308
# [74]	validation_0-mlogloss:0.74227
# [75]	validation_0-mlogloss:0.74149
# [76]	validation_0-mlogloss:0.74073
# [77]	validation_0-mlogloss:0.74001
# [78]	validation_0-mlogloss:0.73931
# [79]	validation_0-mlogloss:0.73866
# [80]	validation_0-mlogloss:0.73799
# [81]	validation_0-mlogloss:0.73730
# [82]	validation_0-mlogloss:0.73671
# [83]	validation_0-mlogloss:0.73610
# [84]	validation_0-mlogloss:0.73547
# [85]	validation_0-mlogloss:0.73483
# [86]	validation_0-mlogloss:0.73425
# [87]	validation_0-mlogloss:0.73372
# [88]	validation_0-mlogloss:0.73320
# [89]	validation_0-mlogloss:0.73269
# [90]	validation_0-mlogloss:0.73223
# [91]	validation_0-mlogloss:0.73174
# [92]	validation_0-mlogloss:0.73129
# [93]	validation_0-mlogloss:0.73086
# [94]	validation_0-mlogloss:0.73040
# [95]	validation_0-mlogloss:0.72996
# [96]	validation_0-mlogloss:0.72955
# [97]	validation_0-mlogloss:0.72916
# [98]	validation_0-mlogloss:0.72879
# [99]	validation_0-mlogloss:0.72842
# [100]	validation_0-mlogloss:0.72809
# [101]	validation_0-mlogloss:0.72772
# [102]	validation_0-mlogloss:0.72740
# [103]	validation_0-mlogloss:0.72710
# [104]	validation_0-mlogloss:0.72675
# [105]	validation_0-mlogloss:0.72645
# [106]	validation_0-mlogloss:0.72613
# [107]	validation_0-mlogloss:0.72586
# [108]	validation_0-mlogloss:0.72560
# [109]	validation_0-mlogloss:0.72531
# [110]	validation_0-mlogloss:0.72505
# [111]	validation_0-mlogloss:0.72479
# [112]	validation_0-mlogloss:0.72457
# [113]	validation_0-mlogloss:0.72432
# [114]	validation_0-mlogloss:0.72410
# [115]	validation_0-mlogloss:0.72389
# [116]	validation_0-mlogloss:0.72370
# [117]	validation_0-mlogloss:0.72351
# [118]	validation_0-mlogloss:0.72330
# [119]	validation_0-mlogloss:0.72307
# [120]	validation_0-mlogloss:0.72282
# [121]	validation_0-mlogloss:0.72262
# [122]	validation_0-mlogloss:0.72245
# [123]	validation_0-mlogloss:0.72228
# [124]	validation_0-mlogloss:0.72210
# [125]	validation_0-mlogloss:0.72192
# [126]	validation_0-mlogloss:0.72174
# [127]	validation_0-mlogloss:0.72159
# [128]	validation_0-mlogloss:0.72142
# [129]	validation_0-mlogloss:0.72126
# [130]	validation_0-mlogloss:0.72111
# [131]	validation_0-mlogloss:0.72094
# [132]	validation_0-mlogloss:0.72078
# [133]	validation_0-mlogloss:0.72063
# [134]	validation_0-mlogloss:0.72048
# [135]	validation_0-mlogloss:0.72034
# [136]	validation_0-mlogloss:0.72021
# [137]	validation_0-mlogloss:0.72010
# [138]	validation_0-mlogloss:0.71995
# [139]	validation_0-mlogloss:0.71984
# [140]	validation_0-mlogloss:0.71973
# [141]	validation_0-mlogloss:0.71964
# [142]	validation_0-mlogloss:0.71953
# [143]	validation_0-mlogloss:0.71943
# [144]	validation_0-mlogloss:0.71932
# [145]	validation_0-mlogloss:0.71923
# [146]	validation_0-mlogloss:0.71917
# [147]	validation_0-mlogloss:0.71909
# [148]	validation_0-mlogloss:0.71900
# [149]	validation_0-mlogloss:0.71893
# [150]	validation_0-mlogloss:0.71882
# [151]	validation_0-mlogloss:0.71879
# [152]	validation_0-mlogloss:0.71873
# [153]	validation_0-mlogloss:0.71867
# [154]	validation_0-mlogloss:0.71860
# [155]	validation_0-mlogloss:0.71852
# [156]	validation_0-mlogloss:0.71843
# [157]	validation_0-mlogloss:0.71837
# [158]	validation_0-mlogloss:0.71826
# [159]	validation_0-mlogloss:0.71818
# [160]	validation_0-mlogloss:0.71809
# [161]	validation_0-mlogloss:0.71803
# [162]	validation_0-mlogloss:0.71798
# [163]	validation_0-mlogloss:0.71792
# [164]	validation_0-mlogloss:0.71787
# [165]	validation_0-mlogloss:0.71785
# [166]	validation_0-mlogloss:0.71781
# [167]	validation_0-mlogloss:0.71774
# [168]	validation_0-mlogloss:0.71768
# [169]	validation_0-mlogloss:0.71763
# [170]	validation_0-mlogloss:0.71759
# [171]	validation_0-mlogloss:0.71753
# [172]	validation_0-mlogloss:0.71749
# [173]	validation_0-mlogloss:0.71746
# [174]	validation_0-mlogloss:0.71744
# [175]	validation_0-mlogloss:0.71743
# [176]	validation_0-mlogloss:0.71739
# [177]	validation_0-mlogloss:0.71736
# [178]	validation_0-mlogloss:0.71736
# [179]	validation_0-mlogloss:0.71732
# [180]	validation_0-mlogloss:0.71731
# [181]	validation_0-mlogloss:0.71728
# [182]	validation_0-mlogloss:0.71728
# [183]	validation_0-mlogloss:0.71725
# [184]	validation_0-mlogloss:0.71723
# [185]	validation_0-mlogloss:0.71721
# [186]	validation_0-mlogloss:0.71720
# [187]	validation_0-mlogloss:0.71716
# [188]	validation_0-mlogloss:0.71713
# [189]	validation_0-mlogloss:0.71709
# [190]	validation_0-mlogloss:0.71705
# [191]	validation_0-mlogloss:0.71700
# [192]	validation_0-mlogloss:0.71698
# [193]	validation_0-mlogloss:0.71693
# [194]	validation_0-mlogloss:0.71688
# [195]	validation_0-mlogloss:0.71683
# [196]	validation_0-mlogloss:0.71679
# [197]	validation_0-mlogloss:0.71677
# [198]	validation_0-mlogloss:0.71674
# [199]	validation_0-mlogloss:0.71671
# [200]	validation_0-mlogloss:0.71669
# [201]	validation_0-mlogloss:0.71669
# [202]	validation_0-mlogloss:0.71668
# [203]	validation_0-mlogloss:0.71668
# [204]	validation_0-mlogloss:0.71667
# [205]	validation_0-mlogloss:0.71666
# [206]	validation_0-mlogloss:0.71666
# [207]	validation_0-mlogloss:0.71668
# [208]	validation_0-mlogloss:0.71669
# [209]	validation_0-mlogloss:0.71668
# [210]	validation_0-mlogloss:0.71669
# [211]	validation_0-mlogloss:0.71670
# [212]	validation_0-mlogloss:0.71671
# [213]	validation_0-mlogloss:0.71671
# [214]	validation_0-mlogloss:0.71670
# [215]	validation_0-mlogloss:0.71671
# [216]	validation_0-mlogloss:0.71669
# [217]	validation_0-mlogloss:0.71670
# [218]	validation_0-mlogloss:0.71670
# [219]	validation_0-mlogloss:0.71671
# [220]	validation_0-mlogloss:0.71672
# [221]	validation_0-mlogloss:0.71673
# [222]	validation_0-mlogloss:0.71674
# [223]	validation_0-mlogloss:0.71676
# [224]	validation_0-mlogloss:0.71676
# [225]	validation_0-mlogloss:0.71678
# [226]	validation_0-mlogloss:0.71681
# [227]	validation_0-mlogloss:0.71682
# [228]	validation_0-mlogloss:0.71680
# [229]	validation_0-mlogloss:0.71680
# [230]	validation_0-mlogloss:0.71680
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          bad       0.60      0.71      0.65     10281
#         good       0.72      0.68      0.70     13708
#      neutral       0.83      0.69      0.75      7057
#
#     accuracy                           0.69     31046
#    macro avg       0.72      0.70      0.70     31046
# weighted avg       0.71      0.69      0.70     31046
#
#
# Weighted F1 Score: 0.6966
#
# Top 10 Most Important Features:
#                               feature  importance
# 63            received_date_dayofweek    0.196096
# 71            Date_released_diff_days    0.138982
# 77         payment_received_diff_days    0.084642
# 85                    discount_amount    0.070099
# 72           Date_estimated_diff_days    0.051487
# 73            Date_received_diff_days    0.043801
# 94                     total_discount    0.029772
# 97                     discount_range    0.016175
# 3   Is_current_loyalty_program_member    0.014069
# 95                       max_discount    0.011073
#
# Making predictions on test set...
#
# Submission file created successfully!
